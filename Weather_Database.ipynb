# %%
# Import dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
# Import the API key.
from config import weather_api_key
# Import the requests library.
import requests

## Imports that we used in the modules, but were not needed for this deliverable.
# import matplotlib.pyplot as plt
# Import the time module.
# import time
# Import the datetime module from the datetime library.
# from datetime import datetime
# Import linear regression from the SciPy stats module.
# from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | saint george
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 1 | khatanga
# Processing Record 7 of Set 1 | airai
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | orlik
# Processing Record 13 of Set 1 | merauke
# Processing Record 14 of Set 1 | tuktoyaktuk
# Processing Record 15 of Set 1 | hualmay
# Processing Record 16 of Set 1 | chiredzi
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | qui nhon
# Processing Record 23 of Set 1 | port lincoln
# Processing Record 24 of Set 1 | faya
# Processing Record 25 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | longyearbyen
# Processing Record 29 of Set 1 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 30 of Set 1 | sol-iletsk
# Processing Record 31 of Set 1 | acapulco
# Processing Record 32 of Set 1 | constitucion
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | mahebourg
# Processing Record 36 of Set 1 | caravelas
# Processing Record 37 of Set 1 | le port
# Processing Record 38 of Set 1 | prieska
# Processing Record 39 of Set 1 | torbay
# Processing Record 40 of Set 1 | bulaevo
# Processing Record 41 of Set 1 | viedma
# Processing Record 42 of Set 1 | kloulklubed
# Processing Record 43 of Set 1 | kapuskasing
# Processing Record 44 of Set 1 | san borja
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | nicoya
# Processing Record 1 of Set 2 | tiznit
# Processing Record 2 of Set 2 | sretensk
# Processing Record 3 of Set 2 | sept-iles
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | mehamn
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | praia da vitoria
# Processing Record 8 of Set 2 | poya
# Processing Record 9 of Set 2 | muros
# Processing Record 10 of Set 2 | port moresby
# Processing Record 11 of Set 2 | mar del plata
# Processing Record 12 of Set 2 | sakakah
# Processing Record 13 of Set 2 | askiz
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | san patricio
# Processing Record 16 of Set 2 | gamba
# Processing Record 17 of Set 2 | greenville
# Processing Record 18 of Set 2 | buala
# Processing Record 19 of Set 2 | jardim
# Processing Record 20 of Set 2 | port augusta
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | gat
# Processing Record 23 of Set 2 | westport
# Processing Record 24 of Set 2 | butaritari
# Processing Record 25 of Set 2 | mamallapuram
# Processing Record 26 of Set 2 | sungairaya
# Processing Record 27 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 28 of Set 2 | samastipur
# Processing Record 29 of Set 2 | mount gambier
# Processing Record 30 of Set 2 | tshela
# Processing Record 31 of Set 2 | itarema
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | hamilton
# Processing Record 34 of Set 2 | avarua
# Processing Record 35 of Set 2 | margate
# Processing Record 36 of Set 2 | beian
# Processing Record 37 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 2 | bredasdorp
# Processing Record 39 of Set 2 | salekhard
# Processing Record 40 of Set 2 | codrington
# Processing Record 41 of Set 2 | koyilandi
# City not found. Skipping...
# Processing Record 42 of Set 2 | lompoc
# Processing Record 43 of Set 2 | chambersburg
# Processing Record 44 of Set 2 | port elizabeth
# Processing Record 45 of Set 2 | bonavista
# Processing Record 46 of Set 2 | udachnyy
# Processing Record 47 of Set 2 | avera
# Processing Record 48 of Set 2 | hofn
# Processing Record 49 of Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 50 of Set 2 | bengkulu
# Processing Record 1 of Set 3 | vestmannaeyjar
# Processing Record 2 of Set 3 | chuy
# Processing Record 3 of Set 3 | provideniya
# Processing Record 4 of Set 3 | zhanakorgan
# Processing Record 5 of Set 3 | sambava
# Processing Record 6 of Set 3 | inuvik
# Processing Record 7 of Set 3 | geraldton
# Processing Record 8 of Set 3 | noyabrsk
# Processing Record 9 of Set 3 | omsukchan
# Processing Record 10 of Set 3 | chumikan
# Processing Record 11 of Set 3 | port hedland
# Processing Record 12 of Set 3 | torit
# Processing Record 13 of Set 3 | cascais
# Processing Record 14 of Set 3 | wawa
# Processing Record 15 of Set 3 | baiquan
# Processing Record 16 of Set 3 | mugla
# Processing Record 17 of Set 3 | luderitz
# Processing Record 18 of Set 3 | krasnyy chikoy
# Processing Record 19 of Set 3 | luwuk
# Processing Record 20 of Set 3 | severo-kurilsk
# Processing Record 21 of Set 3 | flinders
# Processing Record 22 of Set 3 | novhorodka
# Processing Record 23 of Set 3 | nizhnevartovsk
# Processing Record 24 of Set 3 | trairi
# Processing Record 25 of Set 3 | cidreira
# Processing Record 26 of Set 3 | cayenne
# Processing Record 27 of Set 3 | wembley
# Processing Record 28 of Set 3 | dikson
# Processing Record 29 of Set 3 | tiruchchendur
# Processing Record 30 of Set 3 | liwale
# Processing Record 31 of Set 3 | chokurdakh
# Processing Record 32 of Set 3 | jabiru
# City not found. Skipping...
# Processing Record 33 of Set 3 | leningradskiy
# Processing Record 34 of Set 3 | vorotynets
# Processing Record 35 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 3 | bichura
# Processing Record 37 of Set 3 | polis
# Processing Record 38 of Set 3 | kimbe
# Processing Record 39 of Set 3 | mutoko
# Processing Record 40 of Set 3 | planaltina
# Processing Record 41 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 3 | qaanaaq
# Processing Record 43 of Set 3 | husavik
# Processing Record 44 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 3 | wamba
# Processing Record 46 of Set 3 | kahului
# Processing Record 47 of Set 3 | namibe
# Processing Record 48 of Set 3 | saint paul
# Processing Record 49 of Set 3 | mandih
# Processing Record 50 of Set 3 | bougouni
# Processing Record 1 of Set 4 | olafsvik
# Processing Record 2 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 3 of Set 4 | castro
# Processing Record 4 of Set 4 | iqaluit
# Processing Record 5 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 4 | pahrump
# Processing Record 7 of Set 4 | aykhal
# Processing Record 8 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 4 | chimbote
# Processing Record 10 of Set 4 | lebu
# Processing Record 11 of Set 4 | norman wells
# Processing Record 12 of Set 4 | dodge city
# Processing Record 13 of Set 4 | raudeberg
# Processing Record 14 of Set 4 | clyde river
# Processing Record 15 of Set 4 | grindavik
# Processing Record 16 of Set 4 | tasiilaq
# Processing Record 17 of Set 4 | dukat
# Processing Record 18 of Set 4 | kenai
# Processing Record 19 of Set 4 | ribeira grande
# Processing Record 20 of Set 4 | gornopravdinsk
# Processing Record 21 of Set 4 | tabou
# Processing Record 22 of Set 4 | taoudenni
# Processing Record 23 of Set 4 | berlevag
# Processing Record 24 of Set 4 | pacific grove
# Processing Record 25 of Set 4 | kapaa
# Processing Record 26 of Set 4 | ilo
# Processing Record 27 of Set 4 | ludvika
# Processing Record 28 of Set 4 | manuk mangkaw
# Processing Record 29 of Set 4 | nanortalik
# Processing Record 30 of Set 4 | pontianak
# Processing Record 31 of Set 4 | san quintin
# Processing Record 32 of Set 4 | poum
# Processing Record 33 of Set 4 | souillac
# Processing Record 34 of Set 4 | agirish
# Processing Record 35 of Set 4 | bandarbeyla
# Processing Record 36 of Set 4 | abatskoye
# Processing Record 37 of Set 4 | kodiak
# Processing Record 38 of Set 4 | jamame
# Processing Record 39 of Set 4 | teahupoo
# Processing Record 40 of Set 4 | faanui
# Processing Record 41 of Set 4 | yulara
# Processing Record 42 of Set 4 | bom jesus
# Processing Record 43 of Set 4 | carnarvon
# Processing Record 44 of Set 4 | lac du bonnet
# Processing Record 45 of Set 4 | karpogory
# Processing Record 46 of Set 4 | smithers
# Processing Record 47 of Set 4 | batsfjord
# Processing Record 48 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 49 of Set 4 | calvinia
# Processing Record 50 of Set 4 | la sarre
# Processing Record 1 of Set 5 | plettenberg bay
# Processing Record 2 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 3 of Set 5 | vung tau
# Processing Record 4 of Set 5 | macduff
# Processing Record 5 of Set 5 | aasiaat
# Processing Record 6 of Set 5 | san francisco
# Processing Record 7 of Set 5 | saint anthony
# Processing Record 8 of Set 5 | ambon
# Processing Record 9 of Set 5 | fakse ladeplads
# Processing Record 10 of Set 5 | bambous virieux
# Processing Record 11 of Set 5 | cordoba
# Processing Record 12 of Set 5 | kitimat
# Processing Record 13 of Set 5 | saskylakh
# Processing Record 14 of Set 5 | zhigansk
# Processing Record 15 of Set 5 | sorland
# Processing Record 16 of Set 5 | sindou
# Processing Record 17 of Set 5 | turbat
# Processing Record 18 of Set 5 | isangel
# Processing Record 19 of Set 5 | isiro
# Processing Record 20 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 21 of Set 5 | luang prabang
# Processing Record 22 of Set 5 | marystown
# Processing Record 23 of Set 5 | meulaboh
# Processing Record 24 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 5 | pierre
# Processing Record 26 of Set 5 | salym
# Processing Record 27 of Set 5 | whyalla
# Processing Record 28 of Set 5 | hauterive
# Processing Record 29 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 5 | gizo
# Processing Record 31 of Set 5 | yopal
# Processing Record 32 of Set 5 | hemnesberget
# Processing Record 33 of Set 5 | nikolayevka
# Processing Record 34 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 35 of Set 5 | vila franca do campo
# Processing Record 36 of Set 5 | wattegama
# Processing Record 37 of Set 5 | guerrero negro
# Processing Record 38 of Set 5 | penzance
# Processing Record 39 of Set 5 | milovice
# Processing Record 40 of Set 5 | havre-saint-pierre
# Processing Record 41 of Set 5 | ostersund
# Processing Record 42 of Set 5 | nishihara
# Processing Record 43 of Set 5 | hokitika
# Processing Record 44 of Set 5 | port alfred
# Processing Record 45 of Set 5 | talnakh
# Processing Record 46 of Set 5 | high level
# Processing Record 47 of Set 5 | severnyy
# Processing Record 48 of Set 5 | liverpool
# Processing Record 49 of Set 5 | cabo san lucas
# Processing Record 50 of Set 5 | bethel
# Processing Record 1 of Set 6 | berdigestyakh
# Processing Record 2 of Set 6 | kutum
# Processing Record 3 of Set 6 | kavieng
# Processing Record 4 of Set 6 | dunedin
# Processing Record 5 of Set 6 | chicama
# Processing Record 6 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 6 | alofi
# Processing Record 8 of Set 6 | mackay
# Processing Record 9 of Set 6 | tiksi
# Processing Record 10 of Set 6 | la ronge
# Processing Record 11 of Set 6 | thompson
# Processing Record 12 of Set 6 | coahuayana
# Processing Record 13 of Set 6 | krasnoselkup
# Processing Record 14 of Set 6 | esperance
# Processing Record 15 of Set 6 | maniitsoq
# Processing Record 16 of Set 6 | port said
# Processing Record 17 of Set 6 | voyvozh
# Processing Record 18 of Set 6 | mezen
# Processing Record 19 of Set 6 | aksu
# Processing Record 20 of Set 6 | lakes entrance
# Processing Record 21 of Set 6 | ahuimanu
# Processing Record 22 of Set 6 | mmabatho
# Processing Record 23 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 6 | karratha
# Processing Record 25 of Set 6 | georgetown
# Processing Record 26 of Set 6 | constantine
# Processing Record 27 of Set 6 | tatawin
# Processing Record 28 of Set 6 | abu road
# Processing Record 29 of Set 6 | saldanha
# Processing Record 30 of Set 6 | yerbogachen
# Processing Record 31 of Set 6 | japura
# Processing Record 32 of Set 6 | necochea
# Processing Record 33 of Set 6 | upernavik
# Processing Record 34 of Set 6 | jeremie
# Processing Record 35 of Set 6 | xai-xai
# Processing Record 36 of Set 6 | manado
# Processing Record 37 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 38 of Set 6 | malakal
# Processing Record 39 of Set 6 | abong mbang
# Processing Record 40 of Set 6 | yar-sale
# Processing Record 41 of Set 6 | payson
# Processing Record 42 of Set 6 | henties bay
# Processing Record 43 of Set 6 | auki
# Processing Record 44 of Set 6 | oranjemund
# Processing Record 45 of Set 6 | panjab
# Processing Record 46 of Set 6 | fort nelson
# Processing Record 47 of Set 6 | vardo
# Processing Record 48 of Set 6 | clarence town
# Processing Record 49 of Set 6 | mushie
# Processing Record 50 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 7 | evensk
# Processing Record 2 of Set 7 | mount isa
# Processing Record 3 of Set 7 | pingliang
# Processing Record 4 of Set 7 | cherskiy
# Processing Record 5 of Set 7 | bafq
# Processing Record 6 of Set 7 | sola
# Processing Record 7 of Set 7 | allende
# Processing Record 8 of Set 7 | youghal
# Processing Record 9 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 10 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 7 | nouakchott
# Processing Record 12 of Set 7 | acarau
# Processing Record 13 of Set 7 | wladyslawowo
# Processing Record 14 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 15 of Set 7 | te anau
# Processing Record 16 of Set 7 | petropavl
# Processing Record 17 of Set 7 | nikolskoye
# Processing Record 18 of Set 7 | urubicha
# Processing Record 19 of Set 7 | gamboula
# Processing Record 20 of Set 7 | cockburn town
# Processing Record 21 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 22 of Set 7 | salinas
# Processing Record 23 of Set 7 | spearfish
# Processing Record 24 of Set 7 | sao joao da barra
# Processing Record 25 of Set 7 | dillon
# Processing Record 26 of Set 7 | patacamaya
# Processing Record 27 of Set 7 | ballina
# Processing Record 28 of Set 7 | mananjary
# Processing Record 29 of Set 7 | sandviken
# Processing Record 30 of Set 7 | semey
# Processing Record 31 of Set 7 | lorengau
# Processing Record 32 of Set 7 | singapore
# Processing Record 33 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 34 of Set 7 | araouane
# Processing Record 35 of Set 7 | ancud
# Processing Record 36 of Set 7 | huron
# Processing Record 37 of Set 7 | burica
# City not found. Skipping...
# Processing Record 38 of Set 7 | piney green
# Processing Record 39 of Set 7 | klaksvik
# Processing Record 40 of Set 7 | kralendijk
# Processing Record 41 of Set 7 | aksarka
# Processing Record 42 of Set 7 | muisne
# Processing Record 43 of Set 7 | praia
# Processing Record 44 of Set 7 | olinda
# Processing Record 45 of Set 7 | kieta
# Processing Record 46 of Set 7 | lensk
# Processing Record 47 of Set 7 | esil
# Processing Record 48 of Set 7 | asau
# Processing Record 49 of Set 7 | isla vista
# Processing Record 50 of Set 7 | tarakan
# Processing Record 1 of Set 8 | aloleng
# Processing Record 2 of Set 8 | areosa
# Processing Record 3 of Set 8 | steamboat springs
# Processing Record 4 of Set 8 | liberal
# Processing Record 5 of Set 8 | strezhevoy
# Processing Record 6 of Set 8 | huilong
# Processing Record 7 of Set 8 | arraial do cabo
# Processing Record 8 of Set 8 | tura
# Processing Record 9 of Set 8 | iquitos
# Processing Record 10 of Set 8 | osoyoos
# Processing Record 11 of Set 8 | udarnyy
# Processing Record 12 of Set 8 | tessalit
# Processing Record 13 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 8 | ahipara
# Processing Record 15 of Set 8 | vikhorevka
# Processing Record 16 of Set 8 | tambovka
# Processing Record 17 of Set 8 | pevek
# Processing Record 18 of Set 8 | cabadiangan
# Processing Record 19 of Set 8 | the valley
# Processing Record 20 of Set 8 | hay river
# Processing Record 21 of Set 8 | cochrane
# Processing Record 22 of Set 8 | iracoubo
# Processing Record 23 of Set 8 | suhbaatar
# Processing Record 24 of Set 8 | pontal do parana
# Processing Record 25 of Set 8 | waingapu
# Processing Record 26 of Set 8 | waverly
# Processing Record 27 of Set 8 | black river
# Processing Record 28 of Set 8 | coxim
# Processing Record 29 of Set 8 | okhotsk
# Processing Record 30 of Set 8 | ambilobe
# Processing Record 31 of Set 8 | mango
# Processing Record 32 of Set 8 | abay
# Processing Record 33 of Set 8 | indore
# Processing Record 34 of Set 8 | hlotse
# Processing Record 35 of Set 8 | soyo
# Processing Record 36 of Set 8 | ramona
# Processing Record 37 of Set 8 | opuwo
# Processing Record 38 of Set 8 | saint-joseph
# Processing Record 39 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 40 of Set 8 | ust-nera
# Processing Record 41 of Set 8 | pastavy
# Processing Record 42 of Set 8 | okakarara
# Processing Record 43 of Set 8 | teya
# Processing Record 44 of Set 8 | awjilah
# Processing Record 45 of Set 8 | deputatskiy
# Processing Record 46 of Set 8 | las choapas
# Processing Record 47 of Set 8 | sendriceni
# Processing Record 48 of Set 8 | kaitangata
# Processing Record 49 of Set 8 | los llanos de aridane
# Processing Record 50 of Set 8 | tanete
# Processing Record 1 of Set 9 | nago
# Processing Record 2 of Set 9 | yebaishou
# Processing Record 3 of Set 9 | nome
# Processing Record 4 of Set 9 | shasta lake
# Processing Record 5 of Set 9 | bolshoye nagatkino
# Processing Record 6 of Set 9 | naica
# Processing Record 7 of Set 9 | pisco
# Processing Record 8 of Set 9 | naze
# Processing Record 9 of Set 9 | harper
# Processing Record 10 of Set 9 | aswan
# Processing Record 11 of Set 9 | vestmanna
# Processing Record 12 of Set 9 | mindelo
# Processing Record 13 of Set 9 | lisala
# Processing Record 14 of Set 9 | agadez
# Processing Record 15 of Set 9 | shelburne
# Processing Record 16 of Set 9 | tsabong
# Processing Record 17 of Set 9 | jizan
# Processing Record 18 of Set 9 | manokwari
# Processing Record 19 of Set 9 | mvuma
# Processing Record 20 of Set 9 | chivolo
# Processing Record 21 of Set 9 | santiago del estero
# Processing Record 22 of Set 9 | rawson
# Processing Record 23 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 9 | khanino
# Processing Record 25 of Set 9 | chapais
# Processing Record 26 of Set 9 | fairbanks
# Processing Record 27 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 9 | hibbing
# Processing Record 29 of Set 9 | troutdale
# Processing Record 30 of Set 9 | santa rosa
# Processing Record 31 of Set 9 | yabelo
# Processing Record 32 of Set 9 | ponta delgada
# Processing Record 33 of Set 9 | buchanan
# Processing Record 34 of Set 9 | mahon
# Processing Record 35 of Set 9 | shubarkuduk
# Processing Record 36 of Set 9 | channel-port aux basques
# Processing Record 37 of Set 9 | isabela
# Processing Record 38 of Set 9 | kermanshah
# Processing Record 39 of Set 9 | san fernando
# Processing Record 40 of Set 9 | upington
# Processing Record 41 of Set 9 | ilulissat
# Processing Record 42 of Set 9 | dongsheng
# Processing Record 43 of Set 9 | bhunya
# Processing Record 44 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 45 of Set 9 | asosa
# Processing Record 46 of Set 9 | kekri
# Processing Record 47 of Set 9 | banjar
# Processing Record 48 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 49 of Set 9 | san cristobal
# Processing Record 50 of Set 9 | jega
# Processing Record 1 of Set 10 | nuoro
# Processing Record 2 of Set 10 | kruisfontein
# Processing Record 3 of Set 10 | bilibino
# Processing Record 4 of Set 10 | srednekolymsk
# Processing Record 5 of Set 10 | sinnamary
# Processing Record 6 of Set 10 | cagli
# Processing Record 7 of Set 10 | arusha
# Processing Record 8 of Set 10 | kushiro
# Processing Record 9 of Set 10 | susanville
# Processing Record 10 of Set 10 | okha
# Processing Record 11 of Set 10 | fukue
# Processing Record 12 of Set 10 | talcahuano
# Processing Record 13 of Set 10 | gondanglegi
# Processing Record 14 of Set 10 | innisfail
# Processing Record 15 of Set 10 | fare
# Processing Record 16 of Set 10 | porto novo
# Processing Record 17 of Set 10 | launceston
# Processing Record 18 of Set 10 | tikrit
# Processing Record 19 of Set 10 | oktyabrskiy
# Processing Record 20 of Set 10 | domoni
# Processing Record 21 of Set 10 | saint-pierre
# Processing Record 22 of Set 10 | malindi
# Processing Record 23 of Set 10 | khash
# Processing Record 24 of Set 10 | parys
# Processing Record 25 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 26 of Set 10 | tamandare
# Processing Record 27 of Set 10 | abu kamal
# Processing Record 28 of Set 10 | gao
# Processing Record 29 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 10 | kirando
# Processing Record 32 of Set 10 | yanchukan
# City not found. Skipping...
# Processing Record 33 of Set 10 | san andres
# Processing Record 34 of Set 10 | baherden
# Processing Record 35 of Set 10 | comodoro rivadavia
# Processing Record 36 of Set 10 | anadyr
# Processing Record 37 of Set 10 | tuatapere
# Processing Record 38 of Set 10 | northam
# Processing Record 39 of Set 10 | luau
# Processing Record 40 of Set 10 | bereda
# Processing Record 41 of Set 10 | portland
# Processing Record 42 of Set 10 | mahibadhoo
# Processing Record 43 of Set 10 | along
# Processing Record 44 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 10 | palu
# Processing Record 46 of Set 10 | kant
# Processing Record 47 of Set 10 | fernie
# Processing Record 48 of Set 10 | marsa matruh
# Processing Record 49 of Set 10 | atambua
# Processing Record 50 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 11 | limoeiro do ajuru
# Processing Record 2 of Set 11 | touros
# Processing Record 3 of Set 11 | kabwe
# Processing Record 4 of Set 11 | kirakira
# Processing Record 5 of Set 11 | tado
# Processing Record 6 of Set 11 | alice
# Processing Record 7 of Set 11 | wajid
# Processing Record 8 of Set 11 | mascote
# Processing Record 9 of Set 11 | teguise
# Processing Record 10 of Set 11 | port keats
# Processing Record 11 of Set 11 | hasaki
# Processing Record 12 of Set 11 | victoria
# Processing Record 13 of Set 11 | dingle
# Processing Record 14 of Set 11 | abu samrah
# Processing Record 15 of Set 11 | savino
# Processing Record 16 of Set 11 | biak
# Processing Record 17 of Set 11 | kohima
# Processing Record 18 of Set 11 | camacupa
# Processing Record 19 of Set 11 | chipata
# Processing Record 20 of Set 11 | xining
# Processing Record 21 of Set 11 | lagoa
# Processing Record 22 of Set 11 | panaba
# Processing Record 23 of Set 11 | kailua
# Processing Record 24 of Set 11 | north platte
# Processing Record 25 of Set 11 | conchal
# Processing Record 26 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 11 | san miguel de cauri
# Processing Record 28 of Set 11 | phimai
# Processing Record 29 of Set 11 | atikokan
# Processing Record 30 of Set 11 | kavaratti
# Processing Record 31 of Set 11 | verkhnevilyuysk
# Processing Record 32 of Set 11 | oyama
# Processing Record 33 of Set 11 | qinzhou
# Processing Record 34 of Set 11 | el faiyum
# City not found. Skipping...
# Processing Record 35 of Set 11 | ust-ilimsk
# Processing Record 36 of Set 11 | ketchikan
# Processing Record 37 of Set 11 | djambala
# Processing Record 38 of Set 11 | lewiston
# Processing Record 39 of Set 11 | haines junction
# Processing Record 40 of Set 11 | bathsheba
# Processing Record 41 of Set 11 | najran
# Processing Record 42 of Set 11 | rio grande
# Processing Record 43 of Set 11 | pajacuaran
# Processing Record 44 of Set 11 | solsvik
# City not found. Skipping...
# Processing Record 45 of Set 11 | wagar
# Processing Record 46 of Set 11 | ngunguru
# Processing Record 47 of Set 11 | mecca
# Processing Record 48 of Set 11 | belaya gora
# Processing Record 49 of Set 11 | canico
# Processing Record 50 of Set 11 | port hardy
# Processing Record 1 of Set 12 | tilichiki
# Processing Record 2 of Set 12 | nouadhibou
# Processing Record 3 of Set 12 | boyolangu
# Processing Record 4 of Set 12 | aklavik
# Processing Record 5 of Set 12 | goundam
# Processing Record 6 of Set 12 | bonthe
# Processing Record 7 of Set 12 | kuytun
# Processing Record 8 of Set 12 | ornskoldsvik
# Processing Record 9 of Set 12 | flin flon
# Processing Record 10 of Set 12 | coihaique
# Processing Record 11 of Set 12 | santa maria
# Processing Record 12 of Set 12 | sayyan
# Processing Record 13 of Set 12 | sao felix do xingu
# Processing Record 14 of Set 12 | kon tum
# Processing Record 15 of Set 12 | divnoye
# Processing Record 16 of Set 12 | peshkopi
# Processing Record 17 of Set 12 | cosala
# Processing Record 18 of Set 12 | aberystwyth
# Processing Record 19 of Set 12 | bubaque
# Processing Record 20 of Set 12 | skalnyy
# City not found. Skipping...
# Processing Record 21 of Set 12 | yeppoon
# Processing Record 22 of Set 12 | mazatlan
# Processing Record 23 of Set 12 | bartica
# Processing Record 24 of Set 12 | nakamura
# Processing Record 25 of Set 12 | ust-kuyga
# Processing Record 26 of Set 12 | adrar
# Processing Record 27 of Set 12 | palmonostora
# Processing Record 28 of Set 12 | chalchihuites
# Processing Record 29 of Set 12 | unguras
# Processing Record 30 of Set 12 | hit
# Processing Record 31 of Set 12 | prado
# Processing Record 32 of Set 12 | handlova
# Processing Record 33 of Set 12 | buzmeyin
# Processing Record 34 of Set 12 | amot
# Processing Record 35 of Set 12 | tucurui
# Processing Record 36 of Set 12 | beringovskiy
# Processing Record 37 of Set 12 | takoradi
# Processing Record 38 of Set 12 | zapolyarnyy
# Processing Record 39 of Set 12 | kamiiso
# Processing Record 40 of Set 12 | sabang
# Processing Record 41 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 12 | illapel
# Processing Record 43 of Set 12 | baturaja
# Processing Record 44 of Set 12 | tual
# Processing Record 45 of Set 12 | mocuba
# Processing Record 46 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 47 of Set 12 | puerto rico
# Processing Record 48 of Set 12 | sarahan
# Processing Record 49 of Set 12 | komsomolskiy
# Processing Record 50 of Set 12 | namatanai
# Processing Record 1 of Set 13 | ballinrobe
# Processing Record 2 of Set 13 | khuzdar
# Processing Record 3 of Set 13 | bambanglipuro
# Processing Record 4 of Set 13 | narsaq
# Processing Record 5 of Set 13 | umm lajj
# Processing Record 6 of Set 13 | suez
# Processing Record 7 of Set 13 | manyana
# Processing Record 8 of Set 13 | comonfort
# Processing Record 9 of Set 13 | alta floresta
# Processing Record 10 of Set 13 | havoysund
# Processing Record 11 of Set 13 | middlebury
# Processing Record 12 of Set 13 | kaohsiung
# Processing Record 13 of Set 13 | saint marys
# Processing Record 14 of Set 13 | ust-koksa
# Processing Record 15 of Set 13 | atar
# Processing Record 16 of Set 13 | huoqiu
# Processing Record 17 of Set 13 | benguela
# Processing Record 18 of Set 13 | mumford
# Processing Record 19 of Set 13 | ostrovnoy
# Processing Record 20 of Set 13 | sembakung
# Processing Record 21 of Set 13 | katsuura
# Processing Record 22 of Set 13 | qianjiang
# Processing Record 23 of Set 13 | road town
# Processing Record 24 of Set 13 | fort-shevchenko
# Processing Record 25 of Set 13 | jalu
# Processing Record 26 of Set 13 | gravdal
# Processing Record 27 of Set 13 | saint-michel-des-saints
# Processing Record 28 of Set 13 | culebra
# Processing Record 29 of Set 13 | kudahuvadhoo
# Processing Record 30 of Set 13 | edd
# Processing Record 31 of Set 13 | correntina
# Processing Record 32 of Set 13 | puerto madryn
# Processing Record 33 of Set 13 | zahir pir
# Processing Record 34 of Set 13 | tecoanapa
# Processing Record 35 of Set 13 | port hawkesbury
# Processing Record 36 of Set 13 | tabas
# Processing Record 37 of Set 13 | murray bridge
# Processing Record 38 of Set 13 | manaus
# Processing Record 39 of Set 13 | kodinsk
# Processing Record 40 of Set 13 | baffa
# Processing Record 41 of Set 13 | cap malheureux
# Processing Record 42 of Set 13 | vilhena
# Processing Record 43 of Set 13 | tres arroyos
# Processing Record 44 of Set 13 | puerto escondido
# Processing Record 45 of Set 13 | turukhansk
# Processing Record 46 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 47 of Set 13 | emba
# Processing Record 48 of Set 13 | creston
# Processing Record 49 of Set 13 | hurghada
# Processing Record 50 of Set 13 | yellandu
# Processing Record 1 of Set 14 | qalyub
# Processing Record 2 of Set 14 | damghan
# Processing Record 3 of Set 14 | alto araguaia
# Processing Record 4 of Set 14 | puerto berrio
# Processing Record 5 of Set 14 | seoul
# Processing Record 6 of Set 14 | angra dos reis
# Processing Record 7 of Set 14 | vila velha
# Processing Record 8 of Set 14 | clearwater
# Processing Record 9 of Set 14 | san joaquin
# Processing Record 10 of Set 14 | luba
# Processing Record 11 of Set 14 | dinajpur
# Processing Record 12 of Set 14 | port shepstone
# Processing Record 13 of Set 14 | juneau
# Processing Record 14 of Set 14 | surovikino
# Processing Record 15 of Set 14 | kununurra
# Processing Record 16 of Set 14 | altamira
# Processing Record 17 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 14 | dombasle-sur-meurthe
# Processing Record 19 of Set 14 | odweyne
# Processing Record 20 of Set 14 | sitka
# Processing Record 21 of Set 14 | tam ky
# Processing Record 22 of Set 14 | banda aceh
# Processing Record 23 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 14 | poronaysk
# Processing Record 25 of Set 14 | bogatic
# Processing Record 26 of Set 14 | zharkent
# Processing Record 27 of Set 14 | erenhot
# Processing Record 28 of Set 14 | waipawa
# Processing Record 29 of Set 14 | ixtapa
# Processing Record 30 of Set 14 | orodara
# Processing Record 31 of Set 14 | mudyuga
# City not found. Skipping...
# Processing Record 32 of Set 14 | kokoda
# Processing Record 33 of Set 14 | inyonga
# Processing Record 34 of Set 14 | belmonte
# Processing Record 35 of Set 14 | mogilno
# Processing Record 36 of Set 14 | ambunti
# Processing Record 37 of Set 14 | morehead
# Processing Record 38 of Set 14 | huarmey
# Processing Record 39 of Set 14 | khor
# Processing Record 40 of Set 14 | chivay
# Processing Record 41 of Set 14 | dakoro
# Processing Record 42 of Set 14 | kaeo
# Processing Record 43 of Set 14 | balikpapan
# Processing Record 44 of Set 14 | mantua
# Processing Record 45 of Set 14 | asbe teferi
# Processing Record 46 of Set 14 | montrose
# Processing Record 47 of Set 14 | sanger
# Processing Record 48 of Set 14 | goderich
# Processing Record 49 of Set 14 | zyryanka
# Processing Record 50 of Set 14 | elko
# Processing Record 1 of Set 15 | preston
# Processing Record 2 of Set 15 | monrovia
# Processing Record 3 of Set 15 | piopio
# Processing Record 4 of Set 15 | guarapari
# Processing Record 5 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 6 of Set 15 | azul
# Processing Record 7 of Set 15 | cairns
# Processing Record 8 of Set 15 | ulaangom
# Processing Record 9 of Set 15 | nemuro
# Processing Record 10 of Set 15 | alice springs
# Processing Record 11 of Set 15 | polyanka
# Processing Record 12 of Set 15 | yaan
# Processing Record 13 of Set 15 | banmo
# City not found. Skipping...
# Processing Record 14 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 15 | fortuna
# Processing Record 16 of Set 15 | qaqortoq
# Processing Record 17 of Set 15 | yusva
# City not found. Skipping...
# Processing Record 18 of Set 15 | trat
# Processing Record 19 of Set 15 | shieli
# Processing Record 20 of Set 15 | arman
# Processing Record 21 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 22 of Set 15 | timmins
# Processing Record 23 of Set 15 | camaqua
# Processing Record 24 of Set 15 | broome
# Processing Record 25 of Set 15 | alekseyevka
# Processing Record 26 of Set 15 | ulenje
# Processing Record 27 of Set 15 | doschatoye
# Processing Record 28 of Set 15 | zdunska wola
# Processing Record 29 of Set 15 | wanning
# Processing Record 30 of Set 15 | dehui
# Processing Record 31 of Set 15 | piranshahr
# Processing Record 32 of Set 15 | padang
# Processing Record 33 of Set 15 | chapleau
# Processing Record 34 of Set 15 | kayerkan
# Processing Record 35 of Set 15 | kingston
# Processing Record 36 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 15 | la palma
# Processing Record 38 of Set 15 | deer lake
# Processing Record 39 of Set 15 | nantucket
# Processing Record 40 of Set 15 | fengxian
# Processing Record 41 of Set 15 | kurumkan
# Processing Record 42 of Set 15 | mattru
# Processing Record 43 of Set 15 | jiayuguan
# Processing Record 44 of Set 15 | golyshmanovo
# Processing Record 45 of Set 15 | zhangye
# Processing Record 46 of Set 15 | yazman
# Processing Record 47 of Set 15 | oxford
# Processing Record 48 of Set 15 | gushi
# Processing Record 49 of Set 15 | port macquarie
# Processing Record 50 of Set 15 | tiquisio
# Processing Record 1 of Set 16 | lata
# Processing Record 2 of Set 16 | ubinskoye
# Processing Record 3 of Set 16 | terme
# Processing Record 4 of Set 16 | maroslele
# Processing Record 5 of Set 16 | san giljan
# Processing Record 6 of Set 16 | iskateley
# Processing Record 7 of Set 16 | linhares
# Processing Record 8 of Set 16 | zhigalovo
# Processing Record 9 of Set 16 | kisangani
# Processing Record 10 of Set 16 | burnie
# Processing Record 11 of Set 16 | isla mujeres
# Processing Record 12 of Set 16 | homer
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.1927  168.8643     48.47        78          99
# 1  Saint George      US  37.1041 -113.5841     95.63        11           1
# 2       Ushuaia      AR -54.8000  -68.3000     28.06       100          75
# 3        Barrow      US  71.2906 -156.7887     35.62        93          90
# 4      Khatanga      RU  71.9667  102.5000     36.43        99         100
# 5         Airai      TL  -8.9266  125.4092     76.37        44          56
# 6     Busselton      AU -33.6500  115.3333     51.08        79          91
# 7      Hermanus      ZA -34.4187   19.2345     52.90        79          94
# 8  Puerto Ayora      EC  -0.7393  -90.3518     67.55        93          19
# 9         Vaini      TO -21.2000 -175.2000     82.56        83          40
#
#    Wind Speed Current Description
# 0        3.27     overcast clouds
# 1        1.99           clear sky
# 2       17.27          heavy snow
# 3       11.50          light rain
# 4       12.88          light rain
# 5        5.37       broken clouds
# 6       22.62          light rain
# 7       12.33          light rain
# 8        1.99          few clouds
# 9       11.50    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
